# %%
# %cd ..
# Out:
# c:\Users\jeong\Desktop\space-decomposition

# %%
from src.datasets import WiderPerson
from PIL import Image, ImageDraw

import numpy as np
import matplotlib.pyplot as plt

# %%
root = "D:\\datasets\\\WiderPerson"
ds = WiderPerson(root)

# %%
image, label = ds[0]
draw = ImageDraw.Draw(image)
for l in label:
    xyxy = np.array(l[1:])
    xyxy[[0,2]] *= image.size[0]
    xyxy[[1,3]] *= image.size[1]
    xyxy = xyxy.astype(np.int)
    draw.rectangle(tuple(xyxy))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=550x413 at 0x1E6C6E0E160>
